# %%
import numpy as np
import pandas as pd

# %%
duomenys_html = pd.read_html("https://work.studentnews.eu/s/3695/75547-European-countries-the-table-language-population-capital-currency-phone-code-internet-code.htm")

# %%
duomenys_html[1]
# Out:
#              Staat                     Official languages    Population  \
# 0          Austria                                 German   8.4 million
# 1          Belgium  Dutch (north), French (south), German    11 million
# 2         Bulgaria                              Bulgarian     7 million
# 3          Croatia                               Croatian   4.3 million
# 4           Cyprus                         Greek, Turkish       800 000
# 5   Czech Republic                                  Czech    10 million
# 6          Denmark                                 Danish   5.6 million
# 7          Estonia                               Estonian   1.3 million
# 8          Finland                       Finnish, Swedish   5.4 million
# 9           France                                 French    65 million
# 10         Germany                                 German  82.5 million
# 11          Greece                                  Greek    11 million
# ...

# %% [markdown]
# Duomenu irasymas i failus

# %%
duomenys_html[1].to_excel('studentnews.xls', sheet_name = 'Sheet1')
# Out:
# C:\Users\Valdemaras\AppData\Local\Temp\ipykernel_25024\1354837979.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   duomenys_html[1].to_excel('studentnews.xls', sheet_name = 'Sheet1')

# %%
duomenys_html[1].to_csv('studentnews.csv', index=False)

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///studentnews.db')
duomenys_html[1].to_sql('savivaldos', con=engine, index=False)
# Out:
# 32

# %%
duomenys = pd.read_csv('top_20_CA_wildfires.csv')

# %%
duomenys['cause'].unique()
# Out:
# array(['Under Investigation', 'Powerlines', 'Human Related', 'Lightning',
#        'Undetermined'], dtype=object)

# %%
len(duomenys['cause'].unique())
# Out:
# 5

# %%
duomenys['cause'].value_counts()
# Out:
# Human Related          7
# Lightning              7
# Powerlines             4
# Under Investigation    1
# Undetermined           1
# Name: cause, dtype: int64

# %%
duomenys['year'].value_counts()[0:1]
# Out:
# 2018    3
# Name: year, dtype: int64

# %%
gaisru_kiekis = len(duomenys[duomenys['deaths']>=1])
gaisru_kiekis
# Out:
# 10

# %%
indexed_by_year = duomenys.sort_values("year", ascending = False)
indexed_by_year
# Out:
#                   fire_name                cause      month  year  \
# 0         Mendocino Complex  Under Investigation       July  2018
# 15                Camp Fire           Powerlines   November  2018
# 6                      Carr        Human Related       July  2018
# 1                    Thomas           Powerlines   December  2017
# 16                    Rough            Lightning       July  2015
# 4                       Rim        Human Related     August  2013
# 3                      Rush            Lightning     August  2012
# 14                  Station        Human Related     August  2009
# 9   Klamath Theater Complex            Lightning       June  2008
# 12            Basin Complex            Lightning       June  2008
# 5                      Zaca        Human Related       July  2007
# 8                     Witch           Powerlines    October  2007
# 13                 Day Fire        Human Related  September  2006
# ...

# %%
menesiai = {1: 'January',
  2: 'February',
  3: 'March',
  4: 'April',
  5: 'May',
  6: 'June',
  7: 'July',
  8: 'August',
  9: 'September',
  10: 'October',
  11: 'November',
  12: 'December'}

# %%
def month_to_digit(month):
    val_list = list(menesiai.values())
    return val_list.index(month) + 1
    
duomenys['month'] = duomenys['month'].apply(month_to_digit)
duomenys
# Out:
#                   fire_name                cause  month  year  \
# 0         Mendocino Complex  Under Investigation      7  2018
# 1                    Thomas           Powerlines     12  2017
# 2                     Cedar        Human Related     10  2003
# 3                      Rush            Lightning      8  2012
# 4                       Rim        Human Related      8  2013
# 5                      Zaca        Human Related      7  2007
# 6                      Carr        Human Related      7  2018
# 7                  Matilija         Undetermined      9  1932
# 8                     Witch           Powerlines     10  2007
# 9   Klamath Theater Complex            Lightning      6  2008
# 10              Marble Cone            Lightning      7  1977
# 11                   Laguna           Powerlines      9  1970
# 12            Basin Complex            Lightning      6  2008
# 13                 Day Fire        Human Related      9  2006
# ...

# %%
duomenys_html = pd.read_html('https://lt.wikipedia.org/wiki/S%C4%85ra%C5%A1as:Lietuvos_miestai_pagal_gyventojus')

# %%
miestai = duomenys_html[0]
# miestai = miestai.fillna(0)
miestai
# Out:
#      Eilė      Miestas  2020 m.  2019 m.  2011 m.  2001 m.  1989 m.  1979 m.  \
# 0       1      Vilnius  554 866   541212   535631   542287   576747   475825
# 1       2       Kaunas  292 789   286754   315993   378650   419745   370000
# 2       3     Klaipėda  149 431   147892   162360   192954   202929   176648
# 3       4     Šiauliai  101 854   100131   109328   133883   145629   118724
# 4       5    Panevėžys   85 318    87139    99690   119749   126483   102303
# ..    ...          ...      ...      ...      ...      ...      ...      ...
# 98     99      Dusetos      549      559      717      914     1184     1357
# 99    100    Kavarskas      515      527      666      809      972     1113
# 100   101  Smalininkai      397      417      515      653      758      805
# 101   102    Troškūnai      380      377      451      525      672     1174
# 102   103     Panemunė      195      204      274      329      398      506
#
# ...

# %%
miestai["2001\xa0m."]
# Out:
# 0      542287
# 1      378650
# 2      192954
# 3      133883
# 4      119749
#         ...
# 98        914
# 99        809
# 100       653
# 101       525
# 102       329
# Name: 2001 m., Length: 103, dtype: int64

# %%
miestai['Miestas']
# Out:
# 0          Vilnius
# 1           Kaunas
# 2         Klaipėda
# 3         Šiauliai
# 4        Panevėžys
#           ...
# 98         Dusetos
# 99       Kavarskas
# 100    Smalininkai
# 101      Troškūnai
# 102       Panemunė
# Name: Miestas, Length: 103, dtype: object

# %%
# miestai['1897 m.']=miestai['1897 m.'].apply(lambda x: np.where(x.isdigit(),x,'0'))
for col in miestai.columns:
    print(col)
# Out:
# Eilė
# Miestas
# 2020 m.
# 2019 m.
# 2011 m.
# 2001 m.
# 1989 m.
# 1979 m.
# 1970 m.
# 1959 m.
# 1923 m.
# 1897 m.
# Tankumas (2019)

# %%
cols=miestai.columns[2]
cols
# df=miestai.applymap(lambda x: 0 if type(x)==str else x)
# df[cols].info()
# Out:
# '2020\xa0m.'
